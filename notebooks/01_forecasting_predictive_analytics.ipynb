# %% [markdown]
# # LAB 4: Forecasting & Predictive Analytics cho dữ liệu IoT
#
# Bài này dùng UCI Appliances Energy Prediction để dự báo `Appliances` trong bước thời gian kế tiếp. Điểm cần nhớ: Lab 4 không hỏi điểm hiện tại có bất thường không; Lab 4 hỏi giá trị tương lai có thể là bao nhiêu và quyết định vận hành nên thận trọng thế nào.

# %% [markdown]
# ## 1. Load dữ liệu
# Chạy `src/download_data.py` trước nếu muốn tải UCI official dataset. Nếu không có Internet, notebook vẫn chạy bằng sample fallback.

# %%
import sys
import os
import subprocess
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))
os.environ.setdefault('MPLCONFIGDIR', '/tmp/matplotlib-cache')
print('Notebook Python:', sys.executable)

missing = []
for module_name in ['numpy', 'pandas', 'sklearn', 'matplotlib']:
    try:
        __import__(module_name)
    except ModuleNotFoundError:
        missing.append(module_name)

if missing:
    print('Installing missing packages:', missing)
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-r', str(ROOT / 'requirements.txt')])

from utils import load_dataset, make_supervised_frame, clean_supervised_frame, FEATURE_COLUMNS, time_split, regression_metrics, risk_from_prediction, recommendation_from_risk
import pandas as pd
import numpy as np

df = load_dataset()
df.head()
# Out:
# Notebook Python: /usr/local/bin/python3.10
# Installing missing packages: ['numpy', 'pandas', 'sklearn', 'matplotlib']
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas>=2.0
#   Using cached pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# Collecting numpy>=1.24
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Collecting scikit-learn>=1.3
#   Using cached scikit_learn-1.7.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
# Collecting joblib>=1.3
#   Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Collecting matplotlib>=3.7
#   Using cached matplotlib-3.10.9-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
# Collecting fastapi>=0.110
#   Using cached fastapi-0.136.3-py3-none-any.whl (117 kB)
# Collecting uvicorn>=0.29
#   Using cached uvicorn-0.48.0-py3-none-any.whl (71 kB)
# Collecting requests>=2.31
#   Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Collecting jupyter>=1.0
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/admintruong/.local/lib/python3.10/site-packages (from pandas>=2.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 1)) (2.9.0.post0)
# Collecting scipy>=1.8.0
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting pillow>=8
#   Using cached pillow-12.2.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
# Requirement already satisfied: packaging>=20.0 in /home/admintruong/.local/lib/python3.10/site-packages (from matplotlib>=3.7->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 5)) (26.2)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.5.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.63.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=3
#   Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Collecting annotated-doc>=0.0.2
#   Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting pydantic>=2.9.0
#   Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/admintruong/.local/lib/python3.10/site-packages (from fastapi>=0.110->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 6)) (4.15.0)
# Collecting typing-inspection>=0.4.2
#   Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting starlette>=0.46.0
#   Using cached starlette-1.1.0-py3-none-any.whl (72 kB)
# Collecting click>=7.0
#   Using cached click-8.4.1-py3-none-any.whl (116 kB)
# Collecting h11>=0.8
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.16-py3-none-any.whl (74 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.7-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
# Collecting urllib3<3,>=1.26
#   Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Collecting certifi>=2023.5.7
#   Using cached certifi-2026.5.20-py3-none-any.whl (134 kB)
# Collecting notebook
#   Using cached notebook-7.5.6-py3-none-any.whl (14.6 MB)
# Collecting jupyterlab
#   Using cached jupyterlab-4.5.7-py3-none-any.whl (12.5 MB)
# Requirement already satisfied: ipykernel in /home/admintruong/.local/lib/python3.10/site-packages (from jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (7.2.0)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Collecting jupyter-console
#   Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting nbconvert
#   Using cached nbconvert-7.17.1-py3-none-any.whl (261 kB)
# Collecting pydantic-core==2.46.4
#   Using cached pydantic_core-2.46.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /home/admintruong/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=2.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 1)) (1.17.0)
# Collecting anyio<5,>=3.6.2
#   Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Requirement already satisfied: ipython>=7.23.1 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (8.39.0)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (1.8.20)
# Requirement already satisfied: jupyter-client>=8.8.0 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (8.8.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: tornado>=6.4.1 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (6.5.5)
# Requirement already satisfied: psutil>=5.7 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (27.1.0)
# Requirement already satisfied: comm>=0.1.1 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: traitlets>=5.4.0 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (5.15.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /home/admintruong/.local/lib/python3.10/site-packages (from ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (5.9.1)
# Collecting widgetsnbextension~=4.0.14
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Collecting jupyterlab_widgets~=3.0.15
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/admintruong/.local/lib/python3.10/site-packages (from jupyter-console->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (3.0.52)
# Requirement already satisfied: pygments in /home/admintruong/.local/lib/python3.10/site-packages (from jupyter-console->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (2.20.0)
# Collecting jupyter-server<3,>=2.4.0
#   Using cached jupyter_server-2.18.2-py3-none-any.whl (391 kB)
# Collecting httpx<1,>=0.25.0
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting jinja2>=3.0.3
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting async-lru>=1.0.0
#   Using cached async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Collecting tomli>=1.2.2
#   Using cached tomli-2.4.1-py3-none-any.whl (14 kB)
# Collecting notebook-shim>=0.2
#   Using cached notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.10/site-packages (from jupyterlab->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (65.5.0)
# Collecting jupyter-lsp>=2.0.0
#   Using cached jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
# Collecting jupyterlab-server<3,>=2.28.0
#   Using cached jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
# Collecting nbformat>=5.7
#   Using cached nbformat-5.10.4-py3-none-any.whl (78 kB)
# Collecting markupsafe>=2.0
#   Using cached markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Collecting nbclient>=0.5.0
#   Using cached nbclient-0.10.4-py3-none-any.whl (25 kB)
# Collecting bleach[css]!=5.0.0
#   Using cached bleach-6.3.0-py3-none-any.whl (164 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Collecting jupyterlab-pygments
#   Using cached jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting mistune<4,>=2.0.3
#   Using cached mistune-3.2.1-py3-none-any.whl (53 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/admintruong/.local/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette>=0.46.0->fastapi>=0.110->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 6)) (1.3.1)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Using cached tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Requirement already satisfied: decorator in /home/admintruong/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (5.3.1)
# Requirement already satisfied: jedi>=0.16 in /home/admintruong/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (0.20.0)
# Requirement already satisfied: stack_data in /home/admintruong/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /home/admintruong/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/admintruong/.local/lib/python3.10/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (4.9.6)
# Collecting argon2-cffi>=21.1
#   Using cached argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Collecting jupyter-server-terminals>=0.4.4
#   Using cached jupyter_server_terminals-0.5.4-py3-none-any.whl (13 kB)
# Collecting jupyter-events>=0.11.0
#   Using cached jupyter_events-0.12.1-py3-none-any.whl (19 kB)
# Collecting prometheus-client>=0.9
#   Using cached prometheus_client-0.25.0-py3-none-any.whl (64 kB)
# Collecting websocket-client>=1.7
#   Using cached websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Collecting overrides>=5.0
#   Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting terminado>=0.8.3
#   Using cached terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting send2trash>=1.8.2
#   Using cached send2trash-2.1.0-py3-none-any.whl (17 kB)
# Collecting json5>=0.9.0
#   Using cached json5-0.14.0-py3-none-any.whl (36 kB)
# Collecting babel>=2.10
#   Using cached babel-2.18.0-py3-none-any.whl (10.2 MB)
# Collecting jsonschema>=4.18.0
#   Using cached jsonschema-4.26.0-py3-none-any.whl (90 kB)
# Collecting fastjsonschema>=2.15
#   Using cached fastjsonschema-2.21.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: wcwidth in /home/admintruong/.local/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (0.7.0)
# Collecting soupsieve>=1.6.1
#   Using cached soupsieve-2.8.4-py3-none-any.whl (37 kB)
# Collecting argon2-cffi-bindings
#   Using cached argon2_cffi_bindings-25.1.0-cp39-abi3-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (87 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /home/admintruong/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (0.8.7)
# Collecting rpds-py>=0.25.0
#   Using cached rpds_py-0.30.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (390 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting attrs>=22.2.0
#   Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Collecting referencing>=0.28.4
#   Using cached referencing-0.37.0-py3-none-any.whl (26 kB)
# Collecting rfc3986-validator>=0.1.1
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting rfc3339-validator
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting pyyaml>=5.3
#   Using cached pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (770 kB)
# Collecting python-json-logger>=2.0.4
#   Using cached python_json_logger-4.1.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/admintruong/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: pure-eval in /home/admintruong/.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in /home/admintruong/.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: executing>=1.2.0 in /home/admintruong/.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter>=1.0->-r /home/admintruong/AIot/lab4_aiot_forecasting_predictive_analytics_uci_appliances_code/requirements.txt (line 9)) (2.2.1)
# Collecting jsonpointer>1.13
#   Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Collecting isoduration
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting rfc3987-syntax>=1.1.0
#   Using cached rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Collecting webcolors>=24.6.0
#   Using cached webcolors-25.10.0-py3-none-any.whl (14 kB)
# Collecting fqdn
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting cffi>=1.0.1
#   Using cached cffi-2.0.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216 kB)
# Collecting pycparser
#   Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Collecting lark>=1.2.2
#   Using cached lark-1.3.1-py3-none-any.whl (113 kB)
# Collecting arrow>=0.15.0
#   Using cached arrow-1.4.0-py3-none-any.whl (68 kB)
# Installing collected packages: webencodings, pytz, fastjsonschema, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, tzdata, typing-inspection, tomli, tinycss2, threadpoolctl, terminado, soupsieve, send2trash, rpds-py, rfc3986-validator, rfc3339-validator, pyyaml, python-json-logger, pyparsing, pydantic-core, pycparser, prometheus-client, pillow, pandocfilters, overrides, numpy, mistune, markupsafe, lark, kiwisolver, jupyterlab_widgets, jupyterlab-pygments, jsonpointer, json5, joblib, idna, h11, fqdn, fonttools, defusedxml, cycler, click, charset_normalizer, certifi, bleach, babel, attrs, async-lru, annotated-types, annotated-doc, uvicorn, scipy, rfc3987-syntax, requests, referencing, pydantic, pandas, jupyter-server-terminals, jinja2, httpcore, contourpy, cffi, beautifulsoup4, arrow, anyio, starlette, scikit-learn, matplotlib, jsonschema-specifications, isoduration, ipywidgets, httpx, argon2-cffi-bindings, jupyter-console, jsonschema, fastapi, argon2-cffi, nbformat, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, jupyter
# Successfully installed annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.13.0 argon2-cffi-25.1.0 argon2-cffi-bindings-25.1.0 arrow-1.4.0 async-lru-2.3.0 attrs-26.1.0 babel-2.18.0 beautifulsoup4-4.14.3 bleach-6.3.0 certifi-2026.5.20 cffi-2.0.0 charset_normalizer-3.4.7 click-8.4.1 contourpy-1.3.2 cycler-0.12.1 defusedxml-0.7.1 fastapi-0.136.3 fastjsonschema-2.21.2 fonttools-4.63.0 fqdn-1.5.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.16 ipywidgets-8.1.8 isoduration-20.11.0 jinja2-3.1.6 joblib-1.5.3 json5-0.14.0 jsonpointer-3.1.1 jsonschema-4.26.0 jsonschema-specifications-2025.9.1 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.1 jupyter-lsp-2.3.1 jupyter-server-2.18.2 jupyter-server-terminals-0.5.4 jupyterlab-4.5.7 jupyterlab-pygments-0.3.0 jupyterlab-server-2.28.0 jupyterlab_widgets-3.0.16 kiwisolver-1.5.0 lark-1.3.1 markupsafe-3.0.3 matplotlib-3.10.9 mistune-3.2.1 nbclient-0.10.4 nbconvert-7.17.1 nbformat-5.10.4 notebook-7.5.6 notebook-shim-0.2.4 numpy-2.2.6 overrides-7.7.0 pandas-2.3.3 pandocfilters-1.5.1 pillow-12.2.0 prometheus-client-0.25.0 pycparser-3.0 pydantic-2.13.4 pydantic-core-2.46.4 pyparsing-3.3.2 python-json-logger-4.1.0 pytz-2026.2 pyyaml-6.0.3 referencing-0.37.0 requests-2.34.2 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rfc3987-syntax-1.1.0 rpds-py-0.30.0 scikit-learn-1.7.2 scipy-1.15.3 send2trash-2.1.0 soupsieve-2.8.4 starlette-1.1.0 terminado-0.18.1 threadpoolctl-3.6.0 tinycss2-1.4.0 tomli-2.4.1 typing-inspection-0.4.2 tzdata-2026.2 uri-template-1.3.0 urllib3-2.7.0 uvicorn-0.48.0 webcolors-25.10.0 webencodings-0.5.1 websocket-client-1.9.0 widgetsnbextension-4.0.15
# [notice] A new release of pip is available: 23.0.1 -> 26.1.1
# [notice] To update, run: pip3.10 install --upgrade pip
#                  date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0 2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1 2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2 2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3 2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4 2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
df[['date','Appliances','lights','T1','RH_1','T_out']].describe()
# Out:
#                       date    Appliances        lights            T1  \
# count                19735  19735.000000  19735.000000  19735.000000
# mean   2016-03-20 05:30:00     97.694958      3.801875     21.686571
# min    2016-01-11 17:00:00     10.000000      0.000000     16.790000
# 25%    2016-02-14 23:15:00     50.000000      0.000000     20.760000
# 50%    2016-03-20 05:30:00     60.000000      0.000000     21.600000
# 75%    2016-04-23 11:45:00    100.000000      0.000000     22.600000
# max    2016-05-27 18:00:00   1080.000000     70.000000     26.260000
# std                    NaN    102.524891      7.935988      1.606066
#
#                RH_1         T_out
# count  19735.000000  19735.000000
# mean      40.259739      7.411665
# min       27.023333     -5.000000
# 25%       37.333333      3.666667
# 50%       39.656667      6.916667
# 75%       43.066667     10.408333
# max       63.360000     26.100000
# std        3.979299      5.317409

# %% [markdown]
# ## 2. Tạo supervised forecasting table
# Ta tạo target tương lai bằng `target_future = Appliances.shift(-1)`. Với UCI, một bước là 10 phút.

# %%
supervised = make_supervised_frame(df, horizon_steps=1, include_target=True)
supervised = clean_supervised_frame(supervised, FEATURE_COLUMNS, require_target=True)
supervised[['date','Appliances','appliances_lag_1','appliances_rolling_mean_6','target_future']].head()
# Out:
#                  date  Appliances  appliances_lag_1  \
# 0 2016-01-11 21:00:00         110             110.0
# 1 2016-01-11 21:10:00         110             110.0
# 2 2016-01-11 21:20:00         100             110.0
# 3 2016-01-11 21:30:00         100             100.0
# 4 2016-01-11 21:40:00         100             100.0
#
#    appliances_rolling_mean_6  target_future
# 0                 130.000000          110.0
# 1                 125.000000          100.0
# 2                 121.666667          100.0
# 3                 106.666667          100.0
# 4                 105.000000          100.0

# %% [markdown]
# ## 3. Chia train/test theo thời gian
# Không dùng random split cho chuỗi thời gian vì sẽ làm thông tin tương lai rò rỉ ngược về quá khứ.

# %%
train_df, test_df = time_split(supervised, train_ratio=0.75)
train_df['date'].min(), train_df['date'].max(), test_df['date'].min(), test_df['date'].max()
# Out:
# (Timestamp('2016-01-11 21:00:00'),
#  Timestamp('2016-04-23 12:30:00'),
#  Timestamp('2016-04-23 12:40:00'),
#  Timestamp('2016-05-27 17:50:00'))

# %% [markdown]
# ## 4. Baseline: Last Value và Moving Average
# Baseline là hàng rào chống ảo tưởng. Model ML chỉ có ý nghĩa khi được so với quy tắc đơn giản.

# %%
y_test = test_df['target_future']
last_value_pred = test_df['Appliances']
ma6_pred = test_df['appliances_rolling_mean_6']
print('Last value:', regression_metrics(y_test, last_value_pred))
print('Moving average 6:', regression_metrics(y_test, ma6_pred))
# Out:
# Last value: {'mae': 25.7812, 'rmse': 64.4874, 'mape_percent': 21.8438, 'forecast_bias': -0.067}
# Moving average 6: {'mae': 33.7003, 'rmse': 74.0469, 'mape_percent': 29.496, 'forecast_bias': -0.0822}

# %% [markdown]
# ## 5. Train Linear Regression và Random Forest
# Linear Regression dễ giải thích; Random Forest mạnh hơn nhưng cần tránh coi nó là hộp thần kỳ.

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

X_train = train_df[FEATURE_COLUMNS]
y_train = train_df['target_future']
X_test = test_df[FEATURE_COLUMNS]

lin = Pipeline([('scaler', StandardScaler()), ('model', LinearRegression())])
lin.fit(X_train, y_train)
lin_pred = lin.predict(X_test)
print('Linear Regression:', regression_metrics(y_test, lin_pred))

rf = RandomForestRegressor(n_estimators=120, max_depth=12, min_samples_leaf=3, random_state=42, n_jobs=-1)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)
print('Random Forest:', regression_metrics(y_test, rf_pred))
# Out:
# Linear Regression: {'mae': 27.4157, 'rmse': 58.1258, 'mape_percent': 27.2872, 'forecast_bias': 2.5689}
# Random Forest: {'mae': 40.0771, 'rmse': 71.6002, 'mape_percent': 41.5248, 'forecast_bias': 22.3716}

# %% [markdown]
# ## 6. Model nâng cao: GradientBoostingRegressor
# Đây là bản demo nâng cao nhẹ theo hướng boosting. Nó là cầu nối để sinh viên hiểu XGBoost/LightGBM nhưng vẫn chạy bằng scikit-learn, không cần cài thêm thư viện nặng.

# %%
hgb = GradientBoostingRegressor(n_estimators=160, learning_rate=0.05, max_depth=3, min_samples_leaf=3, random_state=42)
hgb.fit(X_train, y_train)
hgb_pred = hgb.predict(X_test)
print('Gradient Boosting:', regression_metrics(y_test, hgb_pred))
# Out:
# Gradient Boosting: {'mae': 39.5115, 'rmse': 66.3859, 'mape_percent': 45.9061, 'forecast_bias': 21.4066}

# %% [markdown]
# ## 7. Từ forecast sang risk_level và recommendation
# Forecast chưa phải quyết định điều khiển. Dự báo cần đi qua risk rule và safety rule.

# %%
thresholds = {'warning': float(np.quantile(y_train, 0.70)), 'high': float(np.quantile(y_train, 0.90)), 'critical': float(np.quantile(y_train, 0.97))}
example_pred = float(hgb_pred[-1])
risk = risk_from_prediction(example_pred, thresholds)
print(example_pred, risk, recommendation_from_risk(risk), thresholds)
# Out:
# 436.12530668080603 CRITICAL HUMAN_CHECK_BEFORE_ACTUATOR_CONTROL {'warning': 90.0, 'high': 210.0, 'critical': 400.0}

# %% [markdown]
# ## 8. Chạy script tổng hợp
# Sau khi hiểu notebook, sinh viên chạy:
#
# ```bash
# python src/train_forecast.py
# python src/plot_results.py
# python src/test_api_local.py
# ```
